# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
data1 = 'pima/diabetes.csv'

# %%
df = pd.DataFrame(data1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ks/501j3zvd5xgf2b84vx00j7w00000gn/T/ipykernel_46703/3866207173.py in ?()
# ----> 1 df = pd.DataFrame(data1)
#
# ~/Library/Application Support/JetBrains/DataSpell2025.3/projects/workspace/.venv/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     886                 )
#     887         # For data is scalar
#     888         else:
#     889             if index is None or columns is None:
# --> 890                 raise ValueError("DataFrame constructor not properly called!")
#     891
#     892             index = ensure_index(index)
#     893             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
